# %% [markdown]
# # Training notebook
# This notebook contains model training steps for the fraud detection system.

# %%
# Example: load data and train
import pandas as pd
df = pd.read_csv('../data/transactions.csv')
df.head()
